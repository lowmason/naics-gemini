# %%
import polars as pl

# %%
(
    pl
    .read_parquet('./data/naics_relation_matrix.parquet')
)
# Out:
# shape: (2_125, 2_125)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ idx_0-cod ┆ idx_1-cod ┆ idx_2-cod ┆ idx_3-cod ┆ … ┆ idx_2121- ┆ idx_2122- ┆ idx_2123- ┆ idx_2124 │
# │ e_11      ┆ e_111     ┆ e_1111    ┆ e_11111   ┆   ┆ code_9281 ┆ code_9281 ┆ code_9281 ┆ -code_92 │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ 1         ┆ 10        ┆ 2         ┆ 8120     │
# │ f64       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0.0       ┆ 1.0       ┆ 3.0       ┆ 4.0       ┆ … ┆ 15.0      ┆ 15.0      ┆ 15.0      ┆ 15.0     │
# │ 1.0       ┆ 0.0       ┆ 1.0       ┆ 3.0       ┆ … ┆ 15.0      ┆ 15.0      ┆ 15.0      ┆ 15.0     │
# ...
